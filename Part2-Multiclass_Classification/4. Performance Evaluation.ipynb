# %%
# imports
from src.config import *
from src.evaluation_multi import *

# %% [markdown]
# # Summary of the optimized models
#
# screened by  `best_cv_accuracy_mean`

# %% [markdown]
# # 1. AdaBoost

# %%
params = {
    "n_estimators": 130,
    "learning_rate": 0.56,      
    "algorithm": "SAMME.R",              
    "random_state": 42
}

ADA_set_6 = model_evaluation_multi(model_class=AdaBoostClassifier, params=params, feature_set='6')
ADA_set_6.get_cv_results()
ADA_set_6.get_test_results()
# Out:
# *************** get_cv_results ***************
# params: {'n_estimators': 130, 'learning_rate': 0.56, 'algorithm': 'SAMME.R', 'random_state': 42}
# cv_f1_macro_mean: 0.9789
# cv_f1_macro_std: 0.0116
# cv_accuracy_mean: 0.9791
# cv_accuracy_std: 0.0114
# cv_precision_macro_mean: 0.9797
# cv_precision_macro_std: 0.0111
# cv_recall_macro_mean: 0.9791
# cv_recall_macro_std: 0.0115
# cv_auc_macro_ovr: 0.9982
#
# *************** get_test_results ***************
# test_accuracy: 0.9722
# test_precision_macro: 0.9700
# test_recall_macro: 0.9704
# test_f1_macro: 0.9700
# test_auc_macro_ovr: 0.9995
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        29
#            2       0.90      0.95      0.92        19
#            3       0.95      0.90      0.93        21
#            4       1.00      1.00      1.00        25
#            5       1.00      1.00      1.00        14
#
# ...

# %% [markdown]
# # 2. ExtraTrees

# %%
params = {
    "n_estimators": 100,
    "max_depth": 4,
    "max_features": None,
    "random_state": 42
}

ETS_set_6 = model_evaluation_multi(model_class=ExtraTreesClassifier, params=params, feature_set='6')
ETS_set_6.get_cv_results()
ETS_set_6.get_test_results()
# Out:
# *************** get_cv_results ***************
# params: {'n_estimators': 100, 'max_depth': 4, 'max_features': None, 'random_state': 42}
# cv_f1_macro_mean: 0.9882
# cv_f1_macro_std: 0.0076
# cv_accuracy_mean: 0.9884
# cv_accuracy_std: 0.0074
# cv_precision_macro_mean: 0.9890
# cv_precision_macro_std: 0.0069
# cv_recall_macro_mean: 0.9880
# cv_recall_macro_std: 0.0079
# cv_auc_macro_ovr: 0.9980
#
# *************** get_test_results ***************
# test_accuracy: 0.9815
# test_precision_macro: 0.9799
# test_recall_macro: 0.9799
# test_f1_macro: 0.9799
# test_auc_macro_ovr: 0.9996
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        29
#            2       0.95      0.95      0.95        19
#            3       0.95      0.95      0.95        21
#            4       1.00      1.00      1.00        25
#            5       1.00      1.00      1.00        14
#
# ...

# %% [markdown]
# # 3. SVC

# %%
params = {
    'kernel': 'linear',
    'C': 0.1,                
    'gamma': 'scale',
    'probability':True
}

SVC_set_6 = model_evaluation_multi(model_class=SVC, params=params, feature_set='6')
SVC_set_6.get_cv_results()
SVC_set_6.get_test_results()
# Out:
# *************** get_cv_results ***************
# params: {'kernel': 'linear', 'C': 0.1, 'gamma': 'scale', 'probability': True}
# cv_f1_macro_mean: 0.9953
# cv_f1_macro_std: 0.0058
# cv_accuracy_mean: 0.9953
# cv_accuracy_std: 0.0057
# cv_precision_macro_mean: 0.9954
# cv_precision_macro_std: 0.0056
# cv_recall_macro_mean: 0.9954
# cv_recall_macro_std: 0.0057
# cv_auc_macro_ovr: 0.9997
#
# *************** get_test_results ***************
# test_accuracy: 1.0000
# test_precision_macro: 1.0000
# test_recall_macro: 1.0000
# test_f1_macro: 1.0000
# test_auc_macro_ovr: 1.0000
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        29
#            2       1.00      1.00      1.00        19
#            3       1.00      1.00      1.00        21
#            4       1.00      1.00      1.00        25
#            5       1.00      1.00      1.00        14
#
#     accuracy                           1.00       108
# ...

# %% [markdown]
# # 4. XGBClassifier

# %%
params = {
    "n_estimators":50,          
    "learning_rate": 0.5,    
    "max_depth": 4,                        
    "random_state": 42
}

XGB_set_6 = model_evaluation_multi(model_class=XGBClassifier, params=params, feature_set='6')
XGB_set_6.get_cv_results()
XGB_set_6.get_test_results()
# Out:
# [Note] Adjusting labels: min label is 1, shifting to start from 0 for XGBClassifier.
#
# *************** get_cv_results ***************
# params: {'n_estimators': 50, 'learning_rate': 0.5, 'max_depth': 4, 'random_state': 42}
# cv_f1_macro_mean: 0.9906
# cv_f1_macro_std: 0.0047
# cv_accuracy_mean: 0.9908
# cv_accuracy_std: 0.0046
# cv_precision_macro_mean: 0.9915
# cv_precision_macro_std: 0.0043
# cv_recall_macro_mean: 0.9903
# cv_recall_macro_std: 0.0049
# cv_auc_macro_ovr: 0.9998
#
# *************** get_test_results ***************
# test_accuracy: 0.9630
# test_precision_macro: 0.9584
# test_recall_macro: 0.9635
# test_f1_macro: 0.9605
# test_auc_macro_ovr: 0.9990
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        29
#            1       0.95      0.95      0.95        19
#            2       0.95      0.90      0.93        21
#            3       0.96      1.00      0.98        25
# ...

# %% [markdown]
# # 5. LogisticRegression

# %%
params = {
    "penalty": "l2", 
    "C": 21.54443,                    
    "solver": "liblinear",   
    "max_iter": 100,                      
    "random_state": 42                            
}

LR_set_6 = model_evaluation_multi(model_class=LogisticRegression, params=params, feature_set='6')
LR_set_6.get_cv_results()
LR_set_6.get_test_results()
# Out:
# *************** get_cv_results ***************
# params: {'penalty': 'l2', 'C': 21.54443, 'solver': 'liblinear', 'max_iter': 100, 'random_state': 42}
# cv_f1_macro_mean: 0.9953
# cv_f1_macro_std: 0.0057
# cv_accuracy_mean: 0.9953
# cv_accuracy_std: 0.0057
# cv_precision_macro_mean: 0.9956
# cv_precision_macro_std: 0.0054
# cv_recall_macro_mean: 0.9954
# cv_recall_macro_std: 0.0057
# cv_auc_macro_ovr: 0.9999
#
# *************** get_test_results ***************
# test_accuracy: 1.0000
# test_precision_macro: 1.0000
# test_recall_macro: 1.0000
# test_f1_macro: 1.0000
# test_auc_macro_ovr: 1.0000
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        29
#            2       1.00      1.00      1.00        19
#            3       1.00      1.00      1.00        21
#            4       1.00      1.00      1.00        25
#            5       1.00      1.00      1.00        14
#
# ...
