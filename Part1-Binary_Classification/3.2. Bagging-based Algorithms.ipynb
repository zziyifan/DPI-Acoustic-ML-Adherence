# %%
# imports
from src.config import *
from src.mlflow_logging import train_and_log_model

# %% [markdown]
# # Bagging-based algorithms
# - RandomForestClassifier
# - ExtraTreesClassifier

# %% [markdown]
# # 1. RandomForestClassifier

# %% [markdown]
# ## 1.1 Using feature set 1

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 5, 2),
    "max_features": ["sqrt", "log2"],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=RandomForestClassifier, param_ranges=param_ranges, feature_set='1', cv_folds=5)
# Out:
# 2024/09/11 22:16:44 INFO mlflow.tracking.fluent: Experiment with name 'RandomForestClassifier_1' does not exist. Creating a new experiment.
# Hyperparameter combinations:   0%|                                                              | 0/40 [00:00<?, ?it/s]2024/09/11 22:16:44 WARNING mlflow.tracking.context.git_context: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh(<full-path-to-git-executable>)
#
# All git commands will error until this is rectified.
#
# This initial message can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|silent|none|n|0: for no message or exception
# ...

# %% [markdown]
# ![image.png](attachment:e5f3cfa4-c0f9-48e1-a1a8-cccfb1b0d0c5.png)

# %% [markdown]
# ## 1.2 Using feature set 2

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 5, 2),
    "max_features": ["sqrt", "log2"],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=RandomForestClassifier, param_ranges=param_ranges, feature_set='2', cv_folds=5)
# Out:
# 2024/09/11 22:36:26 INFO mlflow.tracking.fluent: Experiment with name 'RandomForestClassifier_2' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|█████████████████████████████████████████████████████| 40/40 [06:42<00:00, 10.06s/it]

# %% [markdown]
# ![image.png](attachment:80d1b93e-3aaa-4c3c-b4f4-6a581467a9fa.png)

# %% [markdown]
# ## 1.3 Using feature set 3

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 5, 2),
    "max_features": ["sqrt", "log2"],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=RandomForestClassifier, param_ranges=param_ranges, feature_set='3', cv_folds=5)
# Out:
# 2024/09/11 22:44:38 INFO mlflow.tracking.fluent: Experiment with name 'RandomForestClassifier_3' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|█████████████████████████████████████████████████████| 40/40 [03:49<00:00,  5.75s/it]

# %% [markdown]
# ![image.png](attachment:db421d96-c1de-4dbc-99e4-a0c353ba9229.png)

# %% [markdown]
# ## 1.4 Using feature set 4

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 5, 2),
    "max_features": ["sqrt", "log2"],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=RandomForestClassifier, param_ranges=param_ranges, feature_set='4', cv_folds=5)
# Out:
# 2024/09/11 22:50:06 INFO mlflow.tracking.fluent: Experiment with name 'RandomForestClassifier_4' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|█████████████████████████████████████████████████████| 40/40 [05:09<00:00,  7.75s/it]

# %% [markdown]
# ![image.png](attachment:2700e65d-a599-468e-80f2-6a0b442c09e8.png)

# %% [markdown]
# ## 1.5 Using feature set 5

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 5, 2),
    "max_features": ["sqrt", "log2"],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=RandomForestClassifier, param_ranges=param_ranges, feature_set='5', cv_folds=5)
# Out:
# 2024/09/11 22:56:47 INFO mlflow.tracking.fluent: Experiment with name 'RandomForestClassifier_5' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|█████████████████████████████████████████████████████| 40/40 [05:18<00:00,  7.95s/it]

# %% [markdown]
# ![image.png](attachment:7627508b-d965-4c10-9b03-a3aa461a1024.png)

# %% [markdown]
# ## 1.6 Using feature set 6

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 5, 2),
    "max_features": ["sqrt", "log2"],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=RandomForestClassifier, param_ranges=param_ranges, feature_set='6', cv_folds=5)
# Out:
# 2024/09/11 23:03:50 INFO mlflow.tracking.fluent: Experiment with name 'RandomForestClassifier_6' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|█████████████████████████████████████████████████████| 40/40 [05:15<00:00,  7.89s/it]

# %% [markdown]
# ![image.png](attachment:dfee05b1-4f93-403c-bc1c-2372217b0efa.png)

# %% [markdown]
# # 2. ExtraTreesClassifier

# %% [markdown]
# ## 2.1 Using feature set 1

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 10, 3),
    "max_features": ["sqrt", None],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=ExtraTreesClassifier, param_ranges=param_ranges, feature_set='1', cv_folds=5)

# %% [markdown]
# ### 10 models, 6 hours; 5 models, 2 hours; Interrupted and discarded.
#
# ### Kernel restarted.

# %% [markdown]
# ![image.png](attachment:5d47793f-9d52-45cb-b08a-f80b8769cdc7.png)

# %% [markdown]
# ## 2.2 Using feature set 2

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 10, 3),
    "max_features": ["sqrt", None],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=ExtraTreesClassifier, param_ranges=param_ranges, feature_set='2', cv_folds=5)
# Out:
# 2024/09/12 10:38:53 INFO mlflow.tracking.fluent: Experiment with name 'ExtraTreesClassifier_2' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|██████████████████████████████████████████████████| 60/60 [5:37:33<00:00, 337.56s/it]

# %% [markdown]
# ![image.png](attachment:0d38c899-11c9-4372-bd6a-bd448f3a11a5.png)

# %% [markdown]
# ## 2.3 Using feature set 3

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 10, 3),
    "max_features": ["sqrt", None],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=ExtraTreesClassifier, param_ranges=param_ranges, feature_set='3', cv_folds=5)
# Out:
# 2024/09/12 16:18:11 INFO mlflow.tracking.fluent: Experiment with name 'ExtraTreesClassifier_3' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|█████████████████████████████████████████████████████| 60/60 [05:05<00:00,  5.10s/it]

# %% [markdown]
# ![image.png](attachment:7afb29ad-f4bf-4f55-989e-b8a1ef2a2235.png)

# %% [markdown]
# ## 2.4 Using feature set 4

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 10, 3),
    "max_features": ["sqrt", None],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=ExtraTreesClassifier, param_ranges=param_ranges, feature_set='4', cv_folds=5)
# Out:
# 2024/09/12 22:30:33 INFO mlflow.tracking.fluent: Experiment with name 'ExtraTreesClassifier_4' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|█████████████████████████████████████████████████████| 60/60 [20:55<00:00, 20.93s/it]

# %% [markdown]
# ![image.png](attachment:fc134cb3-a32e-4c76-84b3-3a07f14b5198.png)

# %% [markdown]
# ## 2.5 Using feature set 5

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 10, 3),
    "max_features": ["sqrt", None],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=ExtraTreesClassifier, param_ranges=param_ranges, feature_set='5', cv_folds=5)
# Out:
# 2024/09/12 22:52:58 INFO mlflow.tracking.fluent: Experiment with name 'ExtraTreesClassifier_5' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|█████████████████████████████████████████████████████| 60/60 [17:53<00:00, 17.89s/it]

# %% [markdown]
# ![image.png](attachment:efea9f3c-de01-4832-b134-b96b05d717a0.png)

# %% [markdown]
# ## 2.6 Using feature set 6

# %%
# Parameter ranges
param_ranges = {
    "n_estimators": np.arange(100, 200, 10),
    "max_depth": np.arange(1, 10, 3),
    "max_features": ["sqrt", None],
    "random_state": [42]
}

# Train and log the model
train_and_log_model(model_class=ExtraTreesClassifier, param_ranges=param_ranges, feature_set='6', cv_folds=5)
# Out:
# 2024/09/12 23:12:23 INFO mlflow.tracking.fluent: Experiment with name 'ExtraTreesClassifier_6' does not exist. Creating a new experiment.
# Hyperparameter combinations: 100%|█████████████████████████████████████████████████████| 60/60 [16:59<00:00, 16.99s/it]

# %% [markdown]
# ![image.png](attachment:0512f9a8-250a-439d-bb18-b4bdcdfa6405.png)
